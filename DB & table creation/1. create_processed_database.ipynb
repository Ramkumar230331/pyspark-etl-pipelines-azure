-- %%
DROP DATABASE IF EXISTS f1_processed_incremental CASCADE

-- %%
CREATE DATABASE IF NOT EXISTS f1_processed_incremental
LOCATION "/mnt/formula1dlstudy/processed-incremental"

-- %%
DROP DATABASE IF EXISTS f1_presentation_incrementals CASCADE

-- %%
CREATE DATABASE IF NOT EXISTS f1_presentation_incrementals
LOCATION "/mnt/formula1dlstudy/presentation-incrementals"
