# %%
raw_folder_path = '/mnt/formula1dlstudy/raw'
processed_folder_path = '/mnt/formula1dlstudy/processed'
presentation_folder_path = '/mnt/formula1dlstudy/presentation'

# %%
raw_inc_folder_path = '/mnt/formula1dlstudy/raw-incremental'
processed_inc_folder_path = '/mnt/formula1dlstudy/processed-incremental'
presentation_inc_folder_path = '/mnt/formula1dlstudy/presentation-incrementals'
