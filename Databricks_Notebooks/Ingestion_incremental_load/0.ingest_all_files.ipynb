# %%
v_result = dbutils.notebook.run("1. ingest_circuits_file",0,{"p_data_source":"Formula1","p_file_date":"2021-03-28"})

# %%
v_result = dbutils.notebook.run("2. ingest_race_file",0,{"p_data_source":"Formula1","p_file_date":"2021-03-28"})

# %%
v_result = dbutils.notebook.run("3. ingest_constructors_file",0,{"p_data_source":"Formula1","p_file_date":"2021-03-28"})

# %%
v_result = dbutils.notebook.run("4. ingest_drivers_file",0,{"p_data_source":"Formula1","p_file_date":"2021-03-28"})

# %%
v_result = dbutils.notebook.run("5. ingest_results_file",0,{"p_data_source":"Formula1","p_file_date":"2021-03-28"})

# %%
v_result = dbutils.notebook.run("6. ingest_pitstops_file",0,{"p_data_source":"Formula1","p_file_date":"2021-03-28"})

# %%
v_result = dbutils.notebook.run("7. ingest_laptimes_file",0,{"p_data_source":"Formula1","p_file_date":"2021-03-28"})

# %%
v_result = dbutils.notebook.run("8. ingest_qualifying_file",0,{"p_data_source":"Formula1","p_file_date":"2021-03-28"})

# %%
# %sql
REFRESH TABLE f1_processed_incremental.results;

SELECT race_id, COUNT(race_id)
FROM f1_processed_incremental.results
GROUP BY race_id;
